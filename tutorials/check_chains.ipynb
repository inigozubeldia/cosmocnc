# %%
from getdist import loadMCSamples
from getdist import plots

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
samples = loadMCSamples('/lustre/scratch/data/anicola_hpc-ACT_clustering/output/mcmc/cnc_act_bias_classy_sz_test/cnc_act_bias_classy_sz_test')
# Out:
# WARNING:root:outlier fraction 0.020028612303290415
# /lustre/scratch/data/anicola_hpc-ACT_clustering/output/mcmc/cnc_act_bias_classy_sz_test/cnc_act_bias_classy_sz_test.1.txt
# Removed no burn in

# %%
g = plots.get_single_plotter()
g.triangle_plot(samples, ['A0', 'B0', 'sigma_lnq_act'])
# plt.show()

# %%
samples.samples.shape
# Out:
# (2097, 5)

# %%
for i in range(samples.samples.shape[1]):
    plt.figure()
    plt.plot(samples.samples[:, i], 'k')
